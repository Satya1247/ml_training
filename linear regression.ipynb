# %%
#Linear Regression
#y=mx+c

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/areaprice071.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
#checking whether any missing value in our data

# %%
df.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
#splitting data into independent and dependent variable

# %%
x=df[["area"]]
y=df.price

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
#data visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Area price analysis")
plt.xlabel("Area")
plt.ylabel("price")
plt.scatter(x,y,color="green")

# %%
#install sklearn library to access statistical alogorithms

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model.predict([[1300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([357140.4109589])

# %%
#y=mx+c
m=model.coef_

# %%
m
# Out:
# array([135.78767123])

# %%
c=model.intercept_

# %%
c
# Out:
# 180616.43835616432

# %%
y=m*1300+c

# %%
y
# Out:
# array([357140.4109589])

# %%
y_pred=model.predict(df[["area"]])

# %%
plt.scatter(df.area,df.price,color="green")
plt.plot(df.area,y_pred,color="red")

# %%
#predict price for multiple independent variable

# %%
df=pd.read_csv("Multi.csv")

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
x=df[["area","bedrooms","age"]]
y=df.price

# %%
x
# Out:
#    area  bedrooms  age
# 0  2600         3   20
# 1  3000         4   15
# 2  3200         3   18
# 3  3600         3   30
# 4  4000         5    8

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import  LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[1200,3,7]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([422575.])

# %%
#splitting the data into training and testing part

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.25)

# %%
train_x
# Out:
#    area  bedrooms  age
# 4  4000         5    8
# 2  3200         3   18
# 0  2600         3   20

# %%
train_y
# Out:
# 4    760000
# 2    610000
# 0    550000
# Name: price, dtype: int64

# %%
test_x
# Out:
#    area  bedrooms  age
# 3  3600         3   30
# 1  3000         4   15

# %%
test_y
# Out:
# 3    595000
# 1    565000
# Name: price, dtype: int64

# %%
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
model.predict(test_x)
# Out:
# array([531538.24497058, 625000.        ])

# %%
550000-490000
# Out:
# 60000

# %%
model.score(train_x,train_y)*100
# Out:
# 100.0

# %%
model.score(test_x,test_y)
# Out:
# -15.949765225364477

# %%
#underfitting
#overfitting

# %%
#Decision Tree Classifier:
#it is a supervised
