# %%
#Create a folder and inside the folder paste the csv file(dataset)
#in the same folder create a new notebook and use that notebook to access the imported csv file

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Bmi_male_female (1).csv')

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
row_count,column_count=df.shape

# %%
print(row_count)
print(column_count)
# Out:
# 500
# 4

# %%
#iloc: to access the rows or columns use index numbers
#loc: use row name or column name

# %%
#to access specific rows and columns
#df.iloc[row_index,column_index]
df.iloc[[34,50,78],[1,3]]
# Out:
#     Height  Index
# 34     157      5
# 50     168      5
# 78     176      4

# %%
#to get all columns and specific rows only
df.iloc[[34,50,78],:]
# Out:
#     Gender  Height  Weight  Index
# 34  Female     157     153      5
# 50  Female     168     135      5
# 78  Female     176     122      4

# %%
#to access all rows and specific columns
df.iloc[:,[1,3]]
# Out:
#      Height  Index
# 0       174      4
# 1       189      2
# 2       185      4
# 3       195      3
# 4       149      3
# ..      ...    ...
# 495     150      5
# 496     184      4
# 497     141      5
# 498     150      5
# 499     173      5
#
# [500 rows x 2 columns]

# %%
#loc:
#to access all rows for a specific column
df.loc[:,"Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 495    Female
# 496    Female
# 497    Female
# 498      Male
# 499      Male
# Name: Gender, Length: 500, dtype: object

# %%
#to access all the rows with multiple columns
df.loc[:,["Gender","Height"]]
# Out:
#      Gender  Height
# 0      Male     174
# 1      Male     189
# 2    Female     185
# 3    Female     195
# 4      Male     149
# ..      ...     ...
# 495  Female     150
# 496  Female     184
# 497  Female     141
# 498    Male     150
# 499    Male     173
#
# [500 rows x 2 columns]

# %%
#to access only first five rows
print(df.head())
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
#to access only last five rows
print(df.tail())
# Out:
#      Gender  Height  Weight  Index
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5

# %%
#what ever the numeric columns present in the dataset to get the statistics of those columns use describe()
df.describe()
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
#info() method provides the count of non-null values
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB
# None

# %%
#to get the count of null values
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %%
#filling the missing values u can use fillna()

# %%
df.loc[df.index[-1],"Height"]=np.nan

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male   174.0      96      4
# 1      Male   189.0      87      2
# 2    Female   185.0     110      4
# 3    Female   195.0     104      3
# 4      Male   149.0      61      3
# ..      ...     ...     ...    ...
# 495  Female   150.0     153      5
# 496  Female   184.0     121      4
# 497  Female   141.0     136      5
# 498    Male   150.0      95      5
# 499    Male     NaN     131      5
#
# [500 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  499 non-null    float64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    1
# Weight    0
# Index     0
# dtype: int64

# %%
mean_fill=df["Height"].mean()
mean_fill
# Out:
# 169.93787575150301

# %%
df["Height"].fillna(mean_fill)
# Out:
# 0      174.000000
# 1      189.000000
# 2      185.000000
# 3      195.000000
# 4      149.000000
#           ...
# 495    150.000000
# 496    184.000000
# 497    141.000000
# 498    150.000000
# 499    169.937876
# Name: Height, Length: 500, dtype: float64

# %%
interpolate_fill=df["Height"].interpolate()
interpolate_fill
# Out:
# 0      174.0
# 1      189.0
# 2      185.0
# 3      195.0
# 4      149.0
#        ...
# 495    150.0
# 496    184.0
# 497    141.0
# 498    150.0
# 499    150.0
# Name: Height, Length: 500, dtype: float64

# %%
df.loc[df.index[-1],"Height"]=np.nan

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male   174.0      96      4
# 1      Male   189.0      87      2
# 2    Female   185.0     110      4
# 3    Female   195.0     104      3
# 4      Male   149.0      61      3
# ..      ...     ...     ...    ...
# 495  Female   150.0     153      5
# 496  Female   184.0     121      4
# 497  Female   141.0     136      5
# 498    Male   150.0      95      5
# 499    Male     NaN     131      5
#
# [500 rows x 4 columns]

# %%
df.fillna(23)
# Out:
#      Gender  Height  Weight  Index
# 0      Male   174.0      96      4
# 1      Male   189.0      87      2
# 2    Female   185.0     110      4
# 3    Female   195.0     104      3
# 4      Male   149.0      61      3
# ..      ...     ...     ...    ...
# 495  Female   150.0     153      5
# 496  Female   184.0     121      4
# 497  Female   141.0     136      5
# 498    Male   150.0      95      5
# 499    Male    23.0     131      5
#
# [500 rows x 4 columns]

# %%
df.loc[df.index[-1],"Height"]=np.nan
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male   174.0      96      4
# 1      Male   189.0      87      2
# 2    Female   185.0     110      4
# 3    Female   195.0     104      3
# 4      Male   149.0      61      3
# ..      ...     ...     ...    ...
# 495  Female   150.0     153      5
# 496  Female   184.0     121      4
# 497  Female   141.0     136      5
# 498    Male   150.0      95      5
# 499    Male     NaN     131      5
#
# [500 rows x 4 columns]

# %%
#forward filling
# df.fillna(method="ffill") forwarding value
#df.fillna(method="bfill") backward value

# %%
# df.fillna({"Gender":"Male","Height":130,"Weight":75,"Index":3})

# %%
inplace=True

# %%
df.count()
# Out:
# Gender    500
# Height    499
# Weight    500
# Index     500
# dtype: int64

# %%
#to get the random data with specified percentage
df1=df.sample(frac=0.5)

# %%
df1
# Out:
#      Gender  Height  Weight  Index
# 332    Male   165.0      68      2
# 387  Female   160.0      83      4
# 150  Female   196.0      50      0
# 73     Male   180.0      75      2
# 483    Male   146.0      85      4
# ..      ...     ...     ...    ...
# 225  Female   155.0     144      5
# 388  Female   157.0      66      3
# 407    Male   165.0     143      5
# 11   Female   159.0      80      4
# 32   Female   195.0      65      1
#
# [250 rows x 4 columns]

# %%
df1.count()
# Out:
# Gender    250
# Height    250
# Weight    250
# Index     250
# dtype: int64

# %%
#random_state=0 or 1
df1=df.sample(frac=0.5,random_state=0)
df1
# Out:
#      Gender  Height  Weight  Index
# 90   Female   178.0     154      5
# 254    Male   183.0     147      5
# 283    Male   166.0     107      4
# 445    Male   159.0     140      5
# 461    Male   152.0     132      5
# ..      ...     ...     ...    ...
# 393  Female   183.0      87      3
# 354    Male   190.0      50      0
# 232  Female   184.0      86      3
# 133  Female   167.0     110      4
# 33   Female   160.0     131      5
#
# [250 rows x 4 columns]

# %%
#drop method: in the 1st dataset i have some data
#in the second dataset i have some data
df2=df1.drop(df.index)

# %%
#Matplotlib
import matplotlib.pyplot as plt

# %%
days=[1,2,3,4,5,6,7]
insta_likes=[100,130,145,175,400,50,25]
plt.plot(days,insta_likes)

# %%
plt.title("social media analysis")
plt.xlabel("number of days")
plt.ylabel("number of likes")
plt.plot(days,insta_likes,color="red",marker="o",markerfacecolor="black",linestyle="-.")

# %%
facebook_likes=[111,234,257,334,445,500,600]
youtube_likes=[700,900,1100,1300,1500,2000,2500]
plt.title("social media comparision")
plt.xlabel("number of days")
plt.ylabel("number of likes")
plt.plot(days,insta_likes,color="blue",label="insta",marker="o")
plt.plot(days,facebook_likes,color="red",label="facebook",marker="o")
plt.plot(days,youtube_likes,color="orange",label="youtube",marker="o")
plt.legend(loc="upper left")
plt.grid(color="black",linewidth=2)
plt.xlim(1,5)
plt.ylim(1000,5000)
# Out:
# (1000.0, 5000.0)

# %%
plt.savefig("my_first_plot.png")

# %%
#types of graphs

# %%
#scatter plot

# %%
plt.scatter(days,insta_likes,color="red")

# %%
#bar graph
plt.bar(days,insta_likes,color="orange")
# Out:
# <BarContainer object of 7 artists>

# %%
#pie chart
social_media_list=["insta","fb","whatsapp","utube"]
likes=[121,131,150,500]
plt.pie(likes,labels=social_media_list,radius=2,autopct="%1.1f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7c6a44714a90>,
# ...
#  [Text(2.007507938779978, 0.8999510407435307, 'insta'),
#   Text(0.5903442173589669, 2.119314442226738, 'fb'),
#   Text(-1.4290770588991741, 1.6726442418303085, 'whatsapp'),
#   Text(-0.3736385438146334, -2.1680392613087247, 'utube')],
#  [Text(1.0950043302436243, 0.49088238586010763, '13.4'),
#   Text(0.3220059367412546, 1.1559896957600386, '14.5'),
#   Text(-0.7794965775813676, 0.9123514046347136, '16.6'),
#   Text(-0.20380284208070912, -1.182566869804759, '55.4')])
